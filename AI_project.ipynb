# %%
import numpy as np
import pandas as pd
df=pd.read_csv('housing.csv')

# %%
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# None

# %%
import pandas as pd
df=pd.read_csv('housing.csv')
x=df["total_bedrooms"].mean()
df.fillna(x,inplace=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# None

# %%
w=df["longitude"].mean()
x=df["longitude"].median()
y=df["longitude"].mode()[0]
z=df["longitude"].std()
print("the mean of longitude data is:",w)
print("the median of longitude data is:",x)
print("the mode of longitude data is:",y)
print("the standard deviation of longitude data is:",z)
# Out:
# the mean of longitude data is: -119.56970445736432
# the median of longitude data is: -118.49
# the mode of longitude data is: -118.31
# the standard deviation of longitude data is: 2.0035317235025882

# %%
w=df["latitude"].mean()
x=df["latitude"].median()
y=df["latitude"].mode()[0]
z=df["latitude"].std()
print("the mean of latitude data is:",w)
print("the median of latitude data is:",x)
print("the mode of latitude data is:",y)
print("the standard deviation of latitude data is:",z)
# Out:
# the mean of latitude data is: 35.63186143410853
# the median of latitude data is: 34.26
# the mode of latitude data is: 34.06
# the standard deviation of latitude data is: 2.1359523974571153

# %%
w=df["housing_median_age"].mean()
x=df["housing_median_age"].median()
y=df["housing_median_age"].mode()[0]
z=df["housing_median_age"].std()
print("the mean of housing_median_age data is:",w)
print("the median of housing_median_age data is:",x)
print("the mode of housing_median_age data is:",y)
print("the standard deviation of housing_median_age data is:",z)
# Out:
# the mean of housing_median_age data is: 28.639486434108527
# the median of housing_median_age data is: 29.0
# the mode of housing_median_age data is: 52.0
# the standard deviation of housing_median_age data is: 12.58555761211165

# %%
w=df["total_rooms"].mean()
x=df["total_rooms"].median()
y=df["total_rooms"].mode()[0]
z=df["total_rooms"].std()
print("the mean of total_rooms data is:",w)
print("the median of total_rooms data is:",x)
print("the mode of total_rooms data is:",y)
print("the standard deviation of total_rooms data is:",z)
# Out:
# the mean of total_rooms data is: 2635.7630813953488
# the median of total_rooms data is: 2127.0
# the mode of total_rooms data is: 1527.0
# the standard deviation of total_rooms data is: 2181.615251582795

# %%
w=df["total_bedrooms"].mean()
x=df["total_bedrooms"].median()
y=df["total_bedrooms"].mode()[0]
z=df["total_bedrooms"].std()
print("the mean of total_bedrooms data is:",w)
print("the median of total_bedrooms data is:",x)
print("the mode of total_bedrooms data is:",y)
print("the standard deviation of total_bedrooms data is:",z)
# Out:
# the mean of total_bedrooms data is: 537.8705525375617
# the median of total_bedrooms data is: 438.0
# the mode of total_bedrooms data is: 537.8705525375618
# the standard deviation of total_bedrooms data is: 419.26659232552373

# %%
w=df["population"].mean()
x=df["population"].median()
y=df["population"].mode()[0]
z=df["population"].std()
print("the mean of population data is:",w)
print("the median of population data is:",x)
print("the mode of population data is:",y)
print("the standard deviation of population data is:",z)
# Out:
# the mean of population data is: 1425.4767441860465
# the median of population data is: 1166.0
# the mode of population data is: 891.0
# the standard deviation of population data is: 1132.462121765341

# %%
w=df["households"].mean()
x=df["households"].median()
y=df["households"].mode()[0]
z=df["households"].std()
print("the mean of households data is:",w)
print("the median of households data is:",x)
print("the mode of households data is:",y)
print("the standard deviation of households data is:",z)
# Out:
# the mean of households data is: 499.5396802325581
# the median of households data is: 409.0
# the mode of households data is: 306.0
# the standard deviation of households data is: 382.32975283161073

# %%
w=df["median_income"].mean()
x=df["median_income"].median()
y=df["median_income"].mode()[0]
z=df["median_income"].std()
print("the mean of median_income data is:",w)
print("the median of median_income data is:",x)
print("the mode of median_income data is:",y)
print("the standard deviation of median_income data is:",z)
# Out:
# the mean of median_income data is: 3.8706710029069766
# the median of median_income data is: 3.5347999999999997
# the mode of median_income data is: 3.125
# the standard deviation of median_income data is: 1.8998217179452688

# %%
w=df["median_house_value"].mean()
x=df["median_house_value"].median()
y=df["median_house_value"].mode()[0]
z=df["median_house_value"].std()
print("the mean of median_house_value data is:",w)
print("the median of median_house_value data is:",x)
print("the mode of median_house_value data is:",y)
print("the standard deviation of median_house_value data is:",z)
# Out:
# the mean of median_house_value data is: 206855.81690891474
# the median of median_house_value data is: 179700.0
# the mode of median_house_value data is: 500001.0
# the standard deviation of median_house_value data is: 115395.61587441387

# %%
df['longitude'].value_counts()
# Out:
# longitude
# -118.31    162
# -118.30    160
# -118.29    148
# -118.27    144
# -118.32    142
#           ...
# -123.13      1
# -123.43      1
# -123.12      1
# -116.27      1
# -123.26      1
# Name: count, Length: 844, dtype: int64

# %%
df['latitude'].value_counts()
# Out:
# latitude
# 34.06    244
# 34.05    236
# 34.08    234
# 34.07    231
# 34.04    221
#         ...
# 41.53      1
# 35.86      1
# 35.85      1
# 35.89      1
# 41.20      1
# Name: count, Length: 862, dtype: int64

# %%
df['housing_median_age'].value_counts(0)
# Out:
# housing_median_age
# 52.0    1273
# 36.0     862
# 35.0     824
# 16.0     771
# 17.0     698
# 34.0     689
# 26.0     619
# 33.0     615
# 18.0     570
# 25.0     566
# 32.0     565
# 37.0     537
# 15.0     512
# 19.0     502
# 27.0     488
# 24.0     478
# 30.0     476
# 28.0     471
# 20.0     465
# 29.0     461
# 31.0     458
# 23.0     448
# 21.0     446
# 14.0     412
# 22.0     399
# 38.0     394
# 39.0     369
# 42.0     368
# 44.0     356
# 43.0     353
# 40.0     304
# 13.0     302
# 41.0     296
# 45.0     294
# 10.0     264
# 11.0     254
# 46.0     245
# 5.0      244
# 12.0     238
# 8.0      206
# 9.0      205
# 47.0     198
# 4.0      191
# 48.0     177
# 7.0      175
# 6.0      160
# 50.0     136
# 49.0     134
# 3.0       62
# 2.0       58
# 51.0      48
# 1.0        4
# Name: count, dtype: int64

# %%
df['total_rooms'].value_counts()
# Out:
# total_rooms
# 1527.0    18
# 1613.0    17
# 1582.0    17
# 2127.0    16
# 2053.0    15
#           ..
# 4528.0     1
# 166.0      1
# 9807.0     1
# 5593.0     1
# 4242.0     1
# Name: count, Length: 5926, dtype: int64

# %%
df['total_bedrooms'].value_counts()
# Out:
# total_bedrooms
# 537.870553     207
# 280.000000      55
# 331.000000      51
# 345.000000      50
# 343.000000      49
#               ...
# 2009.000000      1
# 2249.000000      1
# 3114.000000      1
# 1625.000000      1
# 1742.000000      1
# Name: count, Length: 1924, dtype: int64

# %%
df['population'].value_counts()
# Out:
# population
# 891.0     25
# 1052.0    24
# 761.0     24
# 850.0     24
# 1227.0    24
#           ..
# 3700.0     1
# 5558.0     1
# 6437.0     1
# 6242.0     1
# 5534.0     1
# Name: count, Length: 3888, dtype: int64

# %%
df['households'].value_counts()
# Out:
# households
# 306.0     57
# 335.0     56
# 386.0     56
# 282.0     55
# 429.0     54
#           ..
# 2206.0     1
# 1120.0     1
# 1606.0     1
# 1718.0     1
# 2251.0     1
# Name: count, Length: 1815, dtype: int64

# %%
df['median_income'].value_counts()
# Out:
# median_income
# 3.1250     49
# 15.0001    49
# 2.8750     46
# 4.1250     44
# 2.6250     44
#            ..
# 5.6790      1
# 2.5478      1
# 1.9559      1
# 3.7574      1
# 1.4946      1
# Name: count, Length: 12928, dtype: int64

# %%
df['median_house_value'].value_counts()
# Out:
# median_house_value
# 500001.0    965
# 137500.0    122
# 162500.0    117
# 112500.0    103
# 187500.0     93
#            ...
# 34200.0       1
# 46200.0       1
# 352000.0      1
# 307900.0      1
# 385200.0      1
# Name: count, Length: 3842, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('housing.csv')
x=df['median_income']
y=df['median_house_value']
plt.scatter(x,y,color='blue')
plt.title("plot income vs house cost")
plt.xlabel('income')
plt.ylabel("house cost")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('housing.csv')
x=df['longitude']
y=df['median_house_value']
plt.scatter(x,y,color='black')
plt.title("plot longitude vs house cost")
plt.xlabel('longitude')
plt.ylabel("house cost")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('housing.csv')
x=df['latitude']
y=df['median_house_value']
plt.scatter(x,y,color='black')
plt.title("plot latitude vs house cost")
plt.xlabel('latitude')
plt.ylabel("house cost")
plt.show()

# %%
x=df['housing_median_age']
y=df['median_house_value']
fig=plt.figure(figsize=(10,4))
plt.bar(x,y)
plt.title("age vs house cost")
plt.xlabel('median_age')
plt.ylabel('median_house_value')
plt.show()

# %%
x=df['total_rooms']
y=df['median_house_value']
fig=plt.figure(figsize=(10,4))
plt.bar(x,y)
plt.title("rooms vs house cost")
plt.xlabel('rooms')
plt.ylabel('median_house_value')
plt.show()

# %%
x=df['total_bedrooms']
y=df['median_house_value']
fig=plt.figure(figsize=(10,4))
plt.bar(x,y)
plt.title("bedrooms vs house cost")
plt.xlabel('bedrooms')
plt.ylabel('median_house_value')
plt.show()

# %%
x=df['population']
y=df['median_house_value']
fig=plt.figure(figsize=(10,4))
plt.bar(x,y)
plt.title("population vs house cost")
plt.xlabel('population')
plt.ylabel('median_house_value')
plt.show()

# %%
x=df['households']
y=df['median_house_value']
fig=plt.figure(figsize=(10,4))
plt.bar(x,y)
plt.title("households vs house cost")
plt.xlabel('households')
plt.ylabel('median_house_value')
plt.show()

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('housing.csv')
m=df["total_bedrooms"].mean()
df.fillna(m,inplace=True)
from sklearn.model_selection import train_test_split
x=df.drop(['median_house_value'],axis=1)
y=df['median_house_value']
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
train_data=x_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15365    -117.19     33.34                15.0       3310.0           488.0
# 16808    -122.41     37.66                37.0        694.0           188.0
# 3941     -118.59     34.21                34.0       2389.0           521.0
# 10032    -121.07     39.22                52.0       2432.0           495.0
# 10101    -117.97     33.92                32.0       2620.0           398.0
# ...          ...       ...                 ...          ...             ...
# 12047    -117.53     33.88                22.0       2855.0           667.0
# 13325    -117.63     34.06                39.0       1210.0           310.0
# 11818    -121.09     38.97                13.0       1467.0           221.0
# 19845    -119.10     36.40                31.0       1533.0           361.0
# 18544    -122.03     36.97                52.0        403.0            72.0
#
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7250
# INLAND        5256
# NEAR OCEAN    2124
# NEAR BAY      1878
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity,dtype =int)).drop(['ocean_proximity'],axis=1)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15365    -117.19     33.34                15.0     8.105006        6.192362
# 16808    -122.41     37.66                37.0     6.543912        5.241747
# 3941     -118.59     34.21                34.0     7.779049        6.257668
# 10032    -121.07     39.22                52.0     7.796880        6.206576
# 10101    -117.97     33.92                32.0     7.871311        5.988961
# ...          ...       ...                 ...          ...             ...
# 12047    -117.53     33.88                22.0     7.957177        6.504288
# 13325    -117.63     34.06                39.0     7.099202        5.739793
# 11818    -121.09     38.97                13.0     7.291656        5.402677
# 19845    -119.10     36.40                31.0     7.335634        5.891644
# 18544    -122.03     36.97                52.0     6.001415        4.290459
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)
test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
reg.score(x_test,y_test)
# Out:
# 0.6438875935403756

# %%
pred_value=reg.predict(x_test)

# %%
print("linear regression predictions:",pred_value[:3])
# Out:
# linear regression predictions: [159553.19623673 123708.19191979 166704.47968506]

# %%
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
mse=mean_squared_error(y_test,pred_value)
rmse=np.sqrt(mse)
print("Root mean squared error(RMSE) is:",rmse)
# Out:
# Root mean squared error(RMSE) is: 69017.23359232928

# %%
score=r2_score(y_test,pred_value)
score
# Out:
# 0.6438875935403756
